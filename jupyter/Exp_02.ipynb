# %%
import os
import glob
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
base_dir = os.path.abspath('../../..')
datasink_dir = os.path.join(base_dir, 'derivatives', 'datasink')
manualwork_dir = os.path.join(base_dir, 'derivatives', 'manualwork')

# %%
exp_num = '02'
csv_file = os.path.join(datasink_dir, 'csv_work', 'exp-{}'.format(exp_num),
                        'exp-{}_proc_summary.csv'.format(exp_num))
summary_df = pd.read_csv(csv_file)
summary_df
# Out:
#       Segment      N  Volume [mm3] (1)         Mean       Std        fname  \
# 0   Segment_8  43445         146627.00     0.743485   0.77816  scan-02.tsv
# 1   Segment_6   2543           8582.62   442.832000  19.34590  scan-02.tsv
# 2   Segment_1   2803           9460.12   479.196000  31.31510  scan-02.tsv
# 3   Segment_5   2512           8478.00   501.090000  21.68140  scan-02.tsv
# 4   Segment_4   3059          10324.10  1289.600000  77.94280  scan-02.tsv
# ..        ...    ...               ...          ...       ...          ...
# 91  Segment_5   2512           8478.00   401.886000  19.21120  scan-18.tsv
# 92  Segment_4   3059          10324.10   955.491000  46.88240  scan-18.tsv
# 93  Segment_7   2657           8967.38  1002.490000  54.91770  scan-18.tsv
# 94  Segment_3   2678           9038.25  1119.710000  48.68470  scan-18.tsv
# 95  Segment_2   2621           8845.88  1153.580000  77.01360  scan-18.tsv
#
#     region_num          SNR
# 0            0     0.955440
# 1            1   569.075768
# 2            2   615.806518
# 3            3   643.942120
# 4            4  1657.242726
# ..         ...          ...
# 91           3   563.676324
# 92           4  1340.150328
# 93           5  1406.070076
# 94           6  1570.480229
# 95           7  1617.985534
#
# [96 rows x 8 columns]

# %%
sns_plot = sns.relplot(x='region_num',
                       y='Mean',
                       hue=summary_df.fname.tolist(),
                       kind='line',
                       data=summary_df)

# %%
for f in summary_df['fname'].unique():
    print(f)
    scan_dir = os.path.join(base_dir, 'Experiment_' + exp_num)
    f = f.replace('.tsv', '')
    jsons = glob.glob(os.path.join(scan_dir, '*' + f + '*.json'))
    jsonfilename = jsons[0]

    with open(jsonfilename) as json_file:
        print(jsonfilename)
        j_obj = json.load(json_file)
        TE = j_obj['EchoTime']
        TR = j_obj['RepetitionTime']
        FA = j_obj['FlipAngle']
        FA = j_obj['FlipAngle']
        Img_Type = j_obj['ImageType']
    print(TE)
    print(FA)
    print(TR)
    print(Img_Type)

    pass
# Out:
# scan-02.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-02_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_NuFT_ins.json
# 5e-05
# 5
# 0.00265
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-03.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-03_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_NuFT_ins_fatsat.json
# 5e-05
# 5
# 0.00265
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-04.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-04_fl3d_spiral_vibe_cor_fov600mm_2.1x2.1x2.5i_NuFT_ins.json
# 5e-05
# 5
# 0.0027
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-06.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-06_fl3d_spiral_vibe_cor_fov600mm_1.56mmiso_NuFT_g10.json
# 5e-05
# 5
# 0.00316
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-07.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-07_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_SPIRiT_ins.json
# 5e-05
# 5
# 0.0027
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-09.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-09_fl3d_spiral_vibe_cor_1.56mmiso_SPIRiT_g10.json
# 5e-05
# 5
# 0.00312
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-11.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-11_fl3d_spiral_vibe_cor_1.5mmiso_NuFT_g10ie.json
# 5e-05
# 5
# 0.00316
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-13.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-13_fl3d_spiral_vibe_cor_1.5mmiso_NuFT_g10ie.json
# 5e-05
# 5
# 0.00316
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-14.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-14_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_SPIRiT_ins_subtraction.json
# 5e-05
# 5
# 0.00446
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-15.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-15_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_SPIRiT_ins_subtraction_e2.json
# 0.00188
# 5
# 0.00446
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-16.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-16_fl3d_spiral_vibe_cor_2.1x2.1x2.5i_SPIRiT_ins_subtraction_SUB.json
# 5e-05
# 5
# 0.00446
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# scan-18.tsv
# /mnt/4e43a4f6-7402-4881-bcf5-d280e54cc385/Analysis/NEU_Phantom/DCM2NII_NEU/Experiment_02/Exp-02_scan-18_fl3d_spiral_vibe_cor_1.5mmiso_NuFT_g10.json
# 5e-05
# 5
# 0.00316
# ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
